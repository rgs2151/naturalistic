# %%
import cv2
import numpy as np
from tqdm import tqdm
from matplotlib import pyplot as plt

# %%
def read_grayscale_video(path: str) -> np.ndarray:
    cap = cv2.VideoCapture(path)
    frames = []

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        # Convert to grayscale
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        frames.append(gray)

    cap.release()

    if not frames:
        return np.empty((0, 0, 0), dtype=np.uint8)

    arr = np.array(frames, dtype=np.uint8)
    return arr

def get_video_metadata(path):
    cap = cv2.VideoCapture(path)
    fps         = cap.get(cv2.CAP_PROP_FPS)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    cap.release()
    return fps, frame_count, width, height

def resample_gaze_to_frames(gaze: np.ndarray,
                            fps: float,
                            frame_count: int,
                            offset: float = 10.0):
    """
    Resample gaze samples to one (x, y) per video frame, starting at `offset` seconds.
    """
    # Time of each frame
    all_frame_times = np.arange(frame_count) / fps
    # Only keep frames at or after the gaze start time
    valid_frames = all_frame_times >= offset
    target_times = all_frame_times[valid_frames]

    # Duration of the full video
    duration = frame_count / fps
    # Original gaze timestamps span from offset to end
    orig_times = np.linspace(offset, duration, num=gaze.shape[0])

    # Interpolate x and y separately
    x_resampled = np.interp(target_times, orig_times, gaze[:, 0])
    y_resampled = np.interp(target_times, orig_times, gaze[:, 1])

    gaze_per_frame = np.vstack((x_resampled, y_resampled)).T
    return gaze_per_frame, valid_frames

# %%
path = "bin/bangbangyouredead_v4-1.mp4"
video_array = read_grayscale_video(path)
fps, frame_count, width, height = get_video_metadata(path)
print(fps, frame_count, width, height)
# Out:
# 29.97002997002997 14665 720 480

# %%
video_array.shape
# Out:
# (14664, 480, 720)

# %%
gaze = np.load("bin/gaze.npy")
gaze.shape # (num_frames, 2)
# Out:
# (239419, 2)

# %%
gaze_on_frames, frame_mask = resample_gaze_to_frames(gaze, fps, frame_count, offset=10.45)
gaze_on_frames.shape, frame_mask.shape, np.nanmax(gaze_on_frames), np.nanmin(gaze_on_frames), frame_mask.sum()
# Out:
# ((14351, 2),
#  (14665,),
#  np.float64(626.4181468771467),
#  np.float64(19.17312396882625),
#  np.int64(14351))

# %%
def overlay_gaze_on_frames(frames: np.ndarray,
                           gaze_frames: np.ndarray,
                           valid_mask: np.ndarray,
                           pad_x: int,
                           circle_radius: int = 20,
                           circle_color: int = 255) -> np.ndarray:
    """
    Draws a filled circle at each gaze point on a stack of grayscale frames.

    Parameters
    ----------
    frames : np.ndarray
        Video frames as (N, H, W), dtype=uint8.
    gaze_frames : np.ndarray
        Array of (x, y) gaze coordinates, one per valid frame: (M, 2).
    valid_mask : np.ndarray
        Boolean mask of length N indicating which frames have gaze.
    pad_x : int
        Horizontal offset (in px) to map original gaze coords into frame coords.
    circle_radius : int, optional
        Radius of the overlay circle, by default 20.
    circle_color : int, optional
        Gray‐level for the circle (0–255), by default 255 (white).

    Returns
    -------
    np.ndarray
        A new array of frames with the circles drawn, same shape as `frames`.
    """
    out = frames.copy()
    gaze_idx = 0
    N = frames.shape[0]

    for i in tqdm(range(N)):
        if valid_mask[i] and gaze_idx < len(gaze_frames):
            x, y = gaze_frames[gaze_idx]
            gaze_idx += 1
            
            # skip NaNs or out-of-bounds
            if np.isnan(x) or np.isnan(y):
                continue
            xi = int(round(x + pad_x))
            yi = int(round(y))
            
            if (0 <= xi < out.shape[2]) and (0 <= yi < out.shape[1]):
                cv2.circle(out[i], (xi, yi), circle_radius, circle_color, thickness=-1)

    return out

# %%
def save_frames_to_video(frames: np.ndarray,
                         out_path: str,
                         fps: float,
                         is_color: bool = False) -> None:
    """
    Saves a stack of frames to an MP4 file.

    Parameters
    ----------
    frames : np.ndarray
        Array of frames. If is_color=False, shape is (N, H, W);
        if is_color=True, shape is (N, H, W, 3).
    out_path : str
        Path to write the MP4.
    fps : float
        Frames per second for the output video.
    is_color : bool, optional
        Whether the frames are BGR color, by default False.
    """
    N, H, W = frames.shape[:3]
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter(out_path, fourcc, fps, (W, H), isColor=is_color)

    for i in tqdm(range(N)):
        frame = frames[i]
        # if grayscale, VideoWriter expects a BGR frame only if isColor=True,
        # otherwise it will accept (H, W) when isColor=False.
        writer.write(frame)

    writer.release()

# %%
modified = overlay_gaze_on_frames(video_array, gaze_on_frames, frame_mask, pad_x=40)
# Out:
# 100%|██████████| 14664/14664 [00:00<00:00, 262099.32it/s]

# %%
save_frames_to_video(modified, "bin/gaze_overlay.mp4", fps, is_color=False)
# Out:
# 100%|██████████| 14664/14664 [00:13<00:00, 1077.47it/s]

# %%
duration_s = float(14664 / fps)
seconds = np.arange(0, int(np.floor(duration_s)) + 1)
indices = np.array([int(round(fps * s)) for s in seconds])

# %%
cvid = modified[indices]

# %%
for i in tqdm(range(len(cvid))):
    plt.figure()
    plt.imshow(cvid[i], cmap='gray')
    plt.axis('off')
    plt.title(f"Frame {i}")
    plt.savefig(f"export/export_{i}.jpg")
    plt.close()
# Out:
# 100%|██████████| 490/490 [00:18<00:00, 26.06it/s]

# %%
# zip the export folder
# !zip -r export.zip export
# Out:
# updating: export/ (stored 0%)
# updating: export/export_34.jpg (deflated 13%)
# updating: export/export_307.jpg (deflated 17%)
# updating: export/export_65.jpg (deflated 15%)
# updating: export/export_75.jpg (deflated 14%)
# updating: export/export_423.jpg (deflated 12%)
# updating: export/export_74.jpg (deflated 14%)
# updating: export/export_333.jpg (deflated 12%)
# updating: export/export_162.jpg (deflated 13%)
# updating: export/export_205.jpg (deflated 12%)
# updating: export/export_135.jpg (deflated 18%)
# updating: export/export_168.jpg (deflated 12%)
# updating: export/export_356.jpg (deflated 12%)
# updating: export/export_222.jpg (deflated 21%)
# updating: export/export_250.jpg (deflated 11%)
# updating: export/export_484.jpg (deflated 13%)
# updating: export/export_313.jpg (deflated 14%)
# updating: export/export_430.jpg (deflated 13%)
# updating: export/export_407.jpg (deflated 11%)
# updating: export/export_341.jpg (deflated 11%)
# updating: export/export_464.jpg (deflated 13%)
# updating: export/export_448.jpg (deflated 13%)
# updating: export/export_345.jpg (deflated 10%)
# updating: export/export_240.jpg (deflated 13%)
# updating: export/export_332.jpg (deflated 12%)
# updating: export/export_273.jpg (deflated 11%)
# updating: export/export_79.jpg (deflated 14%)
# updating: export/export_193.jpg (deflated 18%)
# updating: export/export_380.jpg (deflated 11%)
# updating: export/export_190.jpg (deflated 16%)
# updating: export/export_26.jpg (deflated 11%)
# updating: export/export_213.jpg (deflated 12%)
# updating: export/export_15.jpg (deflated 8%)
# updating: export/export_9.jpg (deflated 32%)
# updating: export/export_24.jpg (deflated 9%)
# updating: export/export_36.jpg (deflated 11%)
# updating: export/export_111.jpg (deflated 13%)
# updating: export/export_295.jpg (deflated 13%)
# updating: export/export_22.jpg (deflated 9%)
# updating: export/export_293.jpg (deflated 16%)
# updating: export/export_12.jpg (deflated 13%)
# updating: export/export_143.jpg (deflated 11%)
# updating: export/export_275.jpg (deflated 16%)
# updating: export/export_267.jpg (deflated 10%)
# updating: export/export_179.jpg (deflated 19%)
# updating: export/export_261.jpg (deflated 11%)
# updating: export/export_282.jpg (deflated 11%)
# updating: export/export_370.jpg (deflated 18%)
# updating: export/export_366.jpg (deflated 17%)
# updating: export/export_33.jpg (deflated 13%)
# updating: export/export_112.jpg (deflated 13%)
# updating: export/export_155.jpg (deflated 15%)
# updating: export/export_469.jpg (deflated 11%)
# updating: export/export_163.jpg (deflated 9%)
# updating: export/export_200.jpg (deflated 13%)
# updating: export/export_231.jpg (deflated 13%)
# updating: export/export_374.jpg (deflated 13%)
# updating: export/export_488.jpg (deflated 35%)
# updating: export/export_38.jpg (deflated 11%)
# updating: export/export_203.jpg (deflated 13%)
# updating: export/export_351.jpg (deflated 16%)
# updating: export/export_247.jpg (deflated 13%)
# updating: export/export_446.jpg (deflated 10%)
# updating: export/export_417.jpg (deflated 11%)
# updating: export/export_256.jpg (deflated 11%)
# updating: export/export_270.jpg (deflated 10%)
# updating: export/export_64.jpg (deflated 14%)
# updating: export/export_66.jpg (deflated 15%)
# updating: export/export_269.jpg (deflated 11%)
# updating: export/export_421.jpg (deflated 12%)
# updating: export/export_77.jpg (deflated 14%)
# updating: export/export_272.jpg (deflated 11%)
# updating: export/export_72.jpg (deflated 14%)
# updating: export/export_71.jpg (deflated 14%)
# updating: export/export_35.jpg (deflated 12%)
# updating: export/export_463.jpg (deflated 18%)
# updating: export/export_91.jpg (deflated 12%)
# updating: export/export_431.jpg (deflated 14%)
# updating: export/export_412.jpg (deflated 12%)
# updating: export/export_489.jpg (deflated 38%)
# updating: export/export_153.jpg (deflated 16%)
# updating: export/export_223.jpg (deflated 21%)
# updating: export/export_233.jpg (deflated 13%)
# updating: export/export_322.jpg (deflated 13%)
# updating: export/export_56.jpg (deflated 15%)
# updating: export/export_486.jpg (deflated 49%)
# updating: export/export_8.jpg (deflated 32%)
# updating: export/export_249.jpg (deflated 11%)
# updating: export/export_197.jpg (deflated 14%)
# updating: export/export_450.jpg (deflated 10%)
# updating: export/export_61.jpg (deflated 14%)
# updating: export/export_138.jpg (deflated 15%)
# updating: export/export_315.jpg (deflated 16%)
# updating: export/export_369.jpg (deflated 10%)
# updating: export/export_330.jpg (deflated 12%)
# updating: export/export_317.jpg (deflated 14%)
# updating: export/export_109.jpg (deflated 12%)
# updating: export/export_422.jpg (deflated 12%)
# updating: export/export_241.jpg (deflated 13%)
# updating: export/export_17.jpg (deflated 9%)
# updating: export/export_456.jpg (deflated 13%)
# updating: export/export_311.jpg (deflated 15%)
# updating: export/export_292.jpg (deflated 18%)
# updating: export/export_151.jpg (deflated 17%)
# updating: export/export_462.jpg (deflated 11%)
# updating: export/export_466.jpg (deflated 11%)
# updating: export/export_60.jpg (deflated 14%)
# updating: export/export_360.jpg (deflated 15%)
# updating: export/export_354.jpg (deflated 17%)
# updating: export/export_180.jpg (deflated 17%)
# updating: export/export_454.jpg (deflated 13%)
# updating: export/export_18.jpg (deflated 9%)
# updating: export/export_414.jpg (deflated 12%)
# updating: export/export_439.jpg (deflated 15%)
# updating: export/export_474.jpg (deflated 9%)
# updating: export/export_159.jpg (deflated 16%)
# updating: export/export_212.jpg (deflated 12%)
# updating: export/export_323.jpg (deflated 12%)
# updating: export/export_312.jpg (deflated 14%)
# updating: export/export_21.jpg (deflated 9%)
# updating: export/export_11.jpg (deflated 12%)
# updating: export/export_96.jpg (deflated 15%)
# updating: export/export_201.jpg (deflated 13%)
# updating: export/export_284.jpg (deflated 12%)
# updating: export/export_189.jpg (deflated 13%)
# updating: export/export_13.jpg (deflated 13%)
# updating: export/export_364.jpg (deflated 18%)
# updating: export/export_475.jpg (deflated 10%)
# updating: export/export_128.jpg (deflated 11%)
# updating: export/export_6.jpg (deflated 32%)
# updating: export/export_451.jpg (deflated 14%)
# updating: export/export_319.jpg (deflated 19%)
# updating: export/export_80.jpg (deflated 13%)
# updating: export/export_347.jpg (deflated 11%)
# updating: export/export_62.jpg (deflated 14%)
# updating: export/export_371.jpg (deflated 18%)
# updating: export/export_372.jpg (deflated 13%)
# updating: export/export_310.jpg (deflated 14%)
# updating: export/export_410.jpg (deflated 11%)
# updating: export/export_87.jpg (deflated 12%)
# updating: export/export_403.jpg (deflated 11%)
# updating: export/export_402.jpg (deflated 10%)
# updating: export/export_368.jpg (deflated 10%)
# updating: export/export_390.jpg (deflated 12%)
# updating: export/export_164.jpg (deflated 13%)
# updating: export/export_117.jpg (deflated 15%)
# updating: export/export_166.jpg (deflated 12%)
# updating: export/export_85.jpg (deflated 15%)
# updating: export/export_283.jpg (deflated 11%)
# updating: export/export_186.jpg (deflated 14%)
# updating: export/export_376.jpg (deflated 10%)
# updating: export/export_175.jpg (deflated 31%)
# updating: export/export_276.jpg (deflated 15%)
# updating: export/export_432.jpg (deflated 14%)
# updating: export/export_375.jpg (deflated 10%)
# updating: export/export_262.jpg (deflated 11%)
# updating: export/export_435.jpg (deflated 12%)
# updating: export/export_119.jpg (deflated 14%)
# updating: export/export_44.jpg (deflated 11%)
# updating: export/export_14.jpg (deflated 13%)
# updating: export/export_218.jpg (deflated 11%)
# updating: export/export_7.jpg (deflated 32%)
# updating: export/export_443.jpg (deflated 27%)
# updating: export/export_76.jpg (deflated 18%)
# updating: export/export_378.jpg (deflated 19%)
# updating: export/export_301.jpg (deflated 13%)
# updating: export/export_254.jpg (deflated 10%)
# updating: export/export_181.jpg (deflated 14%)
# updating: export/export_290.jpg (deflated 14%)
# updating: export/export_1.jpg (deflated 32%)
# updating: export/export_334.jpg (deflated 12%)
# updating: export/export_23.jpg (deflated 9%)
# updating: export/export_208.jpg (deflated 13%)
# updating: export/export_90.jpg (deflated 12%)
# updating: export/export_102.jpg (deflated 8%)
# updating: export/export_246.jpg (deflated 12%)
# updating: export/export_427.jpg (deflated 12%)
# updating: export/export_303.jpg (deflated 14%)
# updating: export/export_452.jpg (deflated 13%)
# updating: export/export_88.jpg (deflated 12%)
# updating: export/export_20.jpg (deflated 9%)
# updating: export/export_302.jpg (deflated 15%)
# updating: export/export_379.jpg (deflated 13%)
# updating: export/export_396.jpg (deflated 12%)
# updating: export/export_156.jpg (deflated 15%)
# updating: export/export_265.jpg (deflated 11%)
# updating: export/export_472.jpg (deflated 10%)
# updating: export/export_404.jpg (deflated 10%)
# updating: export/export_455.jpg (deflated 13%)
# updating: export/export_365.jpg (deflated 17%)
# updating: export/export_433.jpg (deflated 14%)
# updating: export/export_328.jpg (deflated 12%)
# updating: export/export_220.jpg (deflated 11%)
# updating: export/export_19.jpg (deflated 9%)
# updating: export/export_127.jpg (deflated 15%)
# updating: export/export_242.jpg (deflated 11%)
# updating: export/export_355.jpg (deflated 16%)
# updating: export/export_395.jpg (deflated 12%)
# updating: export/export_409.jpg (deflated 12%)
# updating: export/export_387.jpg (deflated 12%)
# updating: export/export_217.jpg (deflated 11%)
# updating: export/export_101.jpg (deflated 8%)
# updating: export/export_298.jpg (deflated 19%)
# updating: export/export_43.jpg (deflated 12%)
# updating: export/export_408.jpg (deflated 11%)
# updating: export/export_318.jpg (deflated 13%)
# updating: export/export_98.jpg (deflated 16%)
# updating: export/export_346.jpg (deflated 10%)
# updating: export/export_214.jpg (deflated 11%)
# updating: export/export_165.jpg (deflated 13%)
# updating: export/export_106.jpg (deflated 10%)
# updating: export/export_281.jpg (deflated 12%)
# updating: export/export_299.jpg (deflated 28%)
# updating: export/export_268.jpg (deflated 11%)
# updating: export/export_147.jpg (deflated 17%)
# updating: export/export_377.jpg (deflated 10%)
# updating: export/export_289.jpg (deflated 14%)
# updating: export/export_479.jpg (deflated 12%)
# updating: export/export_234.jpg (deflated 14%)
# updating: export/export_278.jpg (deflated 15%)
# updating: export/export_122.jpg (deflated 15%)
# updating: export/export_399.jpg (deflated 12%)
# updating: export/export_461.jpg (deflated 11%)
# updating: export/export_352.jpg (deflated 15%)
# updating: export/export_470.jpg (deflated 12%)
# updating: export/export_304.jpg (deflated 16%)
# updating: export/export_335.jpg (deflated 12%)
# updating: export/export_480.jpg (deflated 12%)
# updating: export/export_183.jpg (deflated 15%)
# updating: export/export_28.jpg (deflated 8%)
# updating: export/export_338.jpg (deflated 15%)
# updating: export/export_280.jpg (deflated 12%)
# updating: export/export_405.jpg (deflated 11%)
# updating: export/export_300.jpg (deflated 26%)
# updating: export/export_126.jpg (deflated 14%)
# updating: export/export_129.jpg (deflated 12%)
# updating: export/export_82.jpg (deflated 13%)
# updating: export/export_286.jpg (deflated 11%)
# updating: export/export_134.jpg (deflated 14%)
# updating: export/export_3.jpg (deflated 32%)
# updating: export/export_59.jpg (deflated 14%)
# updating: export/export_170.jpg (deflated 11%)
# updating: export/export_132.jpg (deflated 14%)
# updating: export/export_291.jpg (deflated 18%)
# updating: export/export_215.jpg (deflated 11%)
# updating: export/export_69.jpg (deflated 14%)
# updating: export/export_81.jpg (deflated 13%)
# updating: export/export_444.jpg (deflated 14%)
# updating: export/export_136.jpg (deflated 14%)
# updating: export/export_361.jpg (deflated 15%)
# updating: export/export_93.jpg (deflated 12%)
# updating: export/export_426.jpg (deflated 12%)
# updating: export/export_447.jpg (deflated 13%)
# updating: export/export_232.jpg (deflated 13%)
# updating: export/export_483.jpg (deflated 11%)
# updating: export/export_67.jpg (deflated 14%)
# updating: export/export_139.jpg (deflated 10%)
# updating: export/export_343.jpg (deflated 11%)
# updating: export/export_420.jpg (deflated 12%)
# updating: export/export_230.jpg (deflated 14%)
# updating: export/export_473.jpg (deflated 10%)
# updating: export/export_305.jpg (deflated 15%)
# updating: export/export_337.jpg (deflated 12%)
# updating: export/export_52.jpg (deflated 18%)
# updating: export/export_167.jpg (deflated 12%)
# updating: export/export_391.jpg (deflated 12%)
# updating: export/export_373.jpg (deflated 13%)
# updating: export/export_413.jpg (deflated 12%)
# updating: export/export_124.jpg (deflated 13%)
# updating: export/export_49.jpg (deflated 19%)
# updating: export/export_348.jpg (deflated 11%)
# updating: export/export_314.jpg (deflated 14%)
# updating: export/export_458.jpg (deflated 11%)
# updating: export/export_58.jpg (deflated 15%)
# updating: export/export_419.jpg (deflated 12%)
# updating: export/export_152.jpg (deflated 15%)
# updating: export/export_357.jpg (deflated 12%)
# updating: export/export_428.jpg (deflated 12%)
# updating: export/export_187.jpg (deflated 12%)
# updating: export/export_125.jpg (deflated 14%)
# updating: export/export_199.jpg (deflated 13%)
# updating: export/export_418.jpg (deflated 12%)
# updating: export/export_192.jpg (deflated 18%)
# updating: export/export_137.jpg (deflated 14%)
# updating: export/export_350.jpg (deflated 12%)
# updating: export/export_434.jpg (deflated 12%)
# updating: export/export_25.jpg (deflated 12%)
# updating: export/export_37.jpg (deflated 11%)
# updating: export/export_359.jpg (deflated 13%)
# updating: export/export_177.jpg (deflated 12%)
# updating: export/export_340.jpg (deflated 12%)
# updating: export/export_42.jpg (deflated 12%)
# updating: export/export_120.jpg (deflated 14%)
# updating: export/export_100.jpg (deflated 9%)
# updating: export/export_146.jpg (deflated 11%)
# updating: export/export_0.jpg (deflated 81%)
# updating: export/export_86.jpg (deflated 12%)
# updating: export/export_252.jpg (deflated 9%)
# updating: export/export_121.jpg (deflated 14%)
# updating: export/export_195.jpg (deflated 14%)
# updating: export/export_411.jpg (deflated 12%)
# updating: export/export_263.jpg (deflated 11%)
# updating: export/export_339.jpg (deflated 68%)
# updating: export/export_398.jpg (deflated 11%)
# updating: export/export_211.jpg (deflated 18%)
# updating: export/export_221.jpg (deflated 21%)
# updating: export/export_194.jpg (deflated 21%)
# updating: export/export_16.jpg (deflated 8%)
# updating: export/export_440.jpg (deflated 16%)
# updating: export/export_367.jpg (deflated 18%)
# updating: export/export_228.jpg (deflated 12%)
# updating: export/export_131.jpg (deflated 19%)
# updating: export/export_142.jpg (deflated 10%)
# updating: export/export_309.jpg (deflated 18%)
# updating: export/export_397.jpg (deflated 11%)
# updating: export/export_481.jpg (deflated 11%)
# updating: export/export_198.jpg (deflated 14%)
# updating: export/export_45.jpg (deflated 12%)
# updating: export/export_384.jpg (deflated 13%)
# updating: export/export_441.jpg (deflated 12%)
# updating: export/export_416.jpg (deflated 12%)
# updating: export/export_383.jpg (deflated 15%)
# updating: export/export_39.jpg (deflated 11%)
# updating: export/export_78.jpg (deflated 14%)
# updating: export/export_141.jpg (deflated 9%)
# updating: export/export_363.jpg (deflated 16%)
# updating: export/export_331.jpg (deflated 11%)
# updating: export/export_279.jpg (deflated 13%)
# updating: export/export_104.jpg (deflated 16%)
# updating: export/export_55.jpg (deflated 19%)
# updating: export/export_184.jpg (deflated 17%)
# updating: export/export_103.jpg (deflated 16%)
# updating: export/export_68.jpg (deflated 14%)
# updating: export/export_308.jpg (deflated 18%)
# updating: export/export_266.jpg (deflated 10%)
# updating: export/export_53.jpg (deflated 18%)
# updating: export/export_353.jpg (deflated 16%)
# updating: export/export_89.jpg (deflated 12%)
# updating: export/export_5.jpg (deflated 32%)
# updating: export/export_253.jpg (deflated 9%)
# updating: export/export_329.jpg (deflated 12%)
# updating: export/export_209.jpg (deflated 14%)
# updating: export/export_358.jpg (deflated 12%)
# updating: export/export_206.jpg (deflated 12%)
# updating: export/export_238.jpg (deflated 11%)
# updating: export/export_229.jpg (deflated 12%)
# updating: export/export_97.jpg (deflated 15%)
# updating: export/export_169.jpg (deflated 10%)
# updating: export/export_73.jpg (deflated 15%)
# updating: export/export_171.jpg (deflated 16%)
# updating: export/export_320.jpg (deflated 19%)
# updating: export/export_285.jpg (deflated 12%)
# updating: export/export_460.jpg (deflated 19%)
# updating: export/export_237.jpg (deflated 10%)
# updating: export/export_116.jpg (deflated 15%)
# updating: export/export_243.jpg (deflated 12%)
# updating: export/export_449.jpg (deflated 11%)
# updating: export/export_95.jpg (deflated 14%)
# updating: export/export_482.jpg (deflated 11%)
# updating: export/export_224.jpg (deflated 21%)
# updating: export/export_178.jpg (deflated 12%)
# updating: export/export_51.jpg (deflated 18%)
# updating: export/export_258.jpg (deflated 12%)
# updating: export/export_487.jpg (deflated 36%)
# updating: export/export_264.jpg (deflated 12%)
# updating: export/export_327.jpg (deflated 12%)
# updating: export/export_107.jpg (deflated 10%)
# updating: export/export_154.jpg (deflated 15%)
# updating: export/export_148.jpg (deflated 18%)
# updating: export/export_465.jpg (deflated 13%)
# updating: export/export_436.jpg (deflated 12%)
# updating: export/export_2.jpg (deflated 32%)
# updating: export/export_392.jpg (deflated 12%)
# updating: export/export_188.jpg (deflated 12%)
# updating: export/export_84.jpg (deflated 14%)
# updating: export/export_176.jpg (deflated 19%)
# updating: export/export_248.jpg (deflated 11%)
# updating: export/export_362.jpg (deflated 16%)
# updating: export/export_244.jpg (deflated 12%)
# updating: export/export_385.jpg (deflated 11%)
# updating: export/export_389.jpg (deflated 12%)
# updating: export/export_239.jpg (deflated 11%)
# updating: export/export_29.jpg (deflated 11%)
# updating: export/export_316.jpg (deflated 15%)
# updating: export/export_48.jpg (deflated 18%)
# updating: export/export_297.jpg (deflated 18%)
# updating: export/export_442.jpg (deflated 12%)
# updating: export/export_92.jpg (deflated 12%)
# updating: export/export_83.jpg (deflated 17%)
# updating: export/export_150.jpg (deflated 14%)
# updating: export/export_344.jpg (deflated 10%)
# updating: export/export_342.jpg (deflated 11%)
# updating: export/export_157.jpg (deflated 16%)
# updating: export/export_50.jpg (deflated 18%)
# updating: export/export_326.jpg (deflated 13%)
# updating: export/export_118.jpg (deflated 15%)
# updating: export/export_108.jpg (deflated 9%)
# updating: export/export_324.jpg (deflated 12%)
# updating: export/export_30.jpg (deflated 11%)
# updating: export/export_32.jpg (deflated 13%)
# updating: export/export_144.jpg (deflated 11%)
# updating: export/export_145.jpg (deflated 10%)
# updating: export/export_210.jpg (deflated 14%)
# updating: export/export_287.jpg (deflated 15%)
# updating: export/export_401.jpg (deflated 10%)
# updating: export/export_271.jpg (deflated 10%)
# updating: export/export_46.jpg (deflated 11%)
# updating: export/export_388.jpg (deflated 12%)
# updating: export/export_47.jpg (deflated 11%)
# updating: export/export_110.jpg (deflated 14%)
# updating: export/export_105.jpg (deflated 9%)
# updating: export/export_476.jpg (deflated 9%)
# updating: export/export_41.jpg (deflated 11%)
# updating: export/export_185.jpg (deflated 16%)
# updating: export/export_453.jpg (deflated 13%)
# updating: export/export_415.jpg (deflated 12%)
# updating: export/export_158.jpg (deflated 10%)
# updating: export/export_54.jpg (deflated 18%)
# updating: export/export_255.jpg (deflated 10%)
# updating: export/export_277.jpg (deflated 16%)
# updating: export/export_113.jpg (deflated 17%)
# updating: export/export_114.jpg (deflated 17%)
# updating: export/export_31.jpg (deflated 11%)
# updating: export/export_438.jpg (deflated 12%)
# updating: export/export_4.jpg (deflated 32%)
# updating: export/export_182.jpg (deflated 18%)
# updating: export/export_468.jpg (deflated 13%)
# updating: export/export_207.jpg (deflated 13%)
# updating: export/export_216.jpg (deflated 11%)
# updating: export/export_196.jpg (deflated 14%)
# updating: export/export_478.jpg (deflated 10%)
# updating: export/export_115.jpg (deflated 15%)
# updating: export/export_130.jpg (deflated 19%)
# updating: export/export_160.jpg (deflated 15%)
# updating: export/export_288.jpg (deflated 14%)
# updating: export/export_386.jpg (deflated 12%)
# updating: export/export_245.jpg (deflated 13%)
# updating: export/export_382.jpg (deflated 13%)
# updating: export/export_251.jpg (deflated 10%)
# updating: export/export_306.jpg (deflated 17%)
# updating: export/export_259.jpg (deflated 12%)
# updating: export/export_394.jpg (deflated 12%)
# updating: export/export_477.jpg (deflated 9%)
# updating: export/export_227.jpg (deflated 12%)
# updating: export/export_63.jpg (deflated 15%)
# updating: export/export_27.jpg (deflated 8%)
# updating: export/export_219.jpg (deflated 11%)
# updating: export/export_325.jpg (deflated 12%)
# updating: export/export_425.jpg (deflated 12%)
# updating: export/export_149.jpg (deflated 19%)
# updating: export/export_161.jpg (deflated 13%)
# updating: export/export_202.jpg (deflated 12%)
# updating: export/export_10.jpg (deflated 32%)
# updating: export/export_257.jpg (deflated 10%)
# updating: export/export_173.jpg (deflated 33%)
# updating: export/export_99.jpg (deflated 14%)
# updating: export/export_94.jpg (deflated 13%)
# updating: export/export_235.jpg (deflated 14%)
# updating: export/export_140.jpg (deflated 9%)
# updating: export/export_172.jpg (deflated 16%)
# updating: export/export_296.jpg (deflated 17%)
# updating: export/export_459.jpg (deflated 11%)
# updating: export/export_393.jpg (deflated 12%)
# updating: export/export_191.jpg (deflated 17%)
# updating: export/export_236.jpg (deflated 12%)
# updating: export/export_133.jpg (deflated 14%)
# updating: export/export_174.jpg (deflated 29%)
# updating: export/export_349.jpg (deflated 14%)
# updating: export/export_123.jpg (deflated 15%)
# updating: export/export_485.jpg (deflated 18%)
# updating: export/export_204.jpg (deflated 12%)
# updating: export/export_429.jpg (deflated 12%)
# updating: export/export_321.jpg (deflated 18%)
# updating: export/export_57.jpg (deflated 15%)
# updating: export/export_406.jpg (deflated 11%)
# updating: export/export_457.jpg (deflated 11%)
# updating: export/export_381.jpg (deflated 10%)
# updating: export/export_471.jpg (deflated 11%)
# updating: export/export_225.jpg (deflated 22%)
# updating: export/export_400.jpg (deflated 12%)
# updating: export/export_336.jpg (deflated 12%)
# updating: export/export_226.jpg (deflated 21%)
# updating: export/export_294.jpg (deflated 15%)
# updating: export/export_467.jpg (deflated 14%)
# updating: export/export_274.jpg (deflated 11%)
# updating: export/export_70.jpg (deflated 14%)
# updating: export/export_424.jpg (deflated 12%)
# updating: export/export_437.jpg (deflated 13%)
# updating: export/export_40.jpg (deflated 12%)
# updating: export/export_260.jpg (deflated 12%)
# updating: export/export_445.jpg (deflated 10%)
